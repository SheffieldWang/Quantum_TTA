# %%
import sys
import pathlib
import numpy as np
import matplotlib.pyplot as plt
import pickle

from tqdm import tqdm


project_path = pathlib.Path.cwd().parent.parent
sys.path.append(f"{project_path}/src")
from tree_utils import LabelBinaryTree

# %%
label_binary_tree = LabelBinaryTree()
label_binary_tree.insert([0,3,6,1,4,7])
label_binary_tree.insert([0,3,6],position='left',parent_val=[0,3,6,1,4,7])
label_binary_tree.insert([1,4,7],position='right',parent_val=[0,3,6,1,4,7])
label_binary_tree.insert([0,6],position='left',parent_val=[0,3,6])
label_binary_tree.insert([3],position='right',parent_val=[0,3,6])
label_binary_tree.insert([0],position='left',parent_val=[0,6])
label_binary_tree.insert([6],position='right',parent_val=[0,6])

label_binary_tree.insert([4,7],position='left',parent_val=[1,4,7])
label_binary_tree.insert([1],position='right',parent_val=[1,4,7])
label_binary_tree.insert([4],position='left',parent_val=[4,7])
label_binary_tree.insert([7],position='right',parent_val=[4,7])

# %%
label_binary_tree.visualize()
# Out:
#                  _______[0, 3, 6, 1, 4, 7]________________
#                 /                                         \
#        _____[0, 3, 6]_                           _____[1, 4, 7]_
#       /               \                         /               \
#   _[0, 6]_           [3]                    _[4, 7]_           [1]
#  /        \                                /        \
# [0]      [6]                              [4]      [7]

# %%
# Save the tree using pickle
tree_label_dir = f"{project_path}/results/tree_results/"
pathlib.Path(tree_label_dir).mkdir(parents=True, exist_ok=True)
tree_label_path = f"{tree_label_dir}mnist_036147_tree_label.pkl"
with open(tree_label_path, 'wb') as f:
    pickle.dump(label_binary_tree, f)

print(f"Tree saved as {tree_label_path}")
# Out:
# Tree saved as /home/qcql/code/QAdaboost_Huawei/results/tree_results/mnist_036147_tree_label.pkl
